# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# # STEP-1 : Understanding the data

# %%
df = pd.read_csv("BlackFriday.csv")

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# 2                 NaN                 NaN      1422
# 3                14.0                 NaN      1057
# 4                 NaN                 NaN      7969

# %% [raw]
# Changing the datatype of User_ID and Product_Category_1 to str and float respectively for correct analysis and for future use

# %%
df = df.astype({'User_ID' : str,'Product_Category_1' : float})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     537577 non-null  object
#  1   Product_ID                  537577 non-null  object
#  2   Gender                      537577 non-null  object
#  3   Age                         537577 non-null  object
#  4   Occupation                  537577 non-null  int64
#  5   City_Category               537577 non-null  object
#  6   Stay_In_Current_City_Years  537577 non-null  object
#  7   Marital_Status              537577 non-null  int64
#  8   Product_Category_1          537577 non-null  float64
#  9   Product_Category_2          370591 non-null  float64
#  10  Product_Category_3          164278 non-null  float64
#  11  Purchase                    537577 non-null  int64
# dtypes: float64(3), int64(3), object(6)
# memory usage: 49.2+ MB

# %%
df.describe()
# Out:
#          Occupation  Marital_Status  Product_Category_1  Product_Category_2  \
# count  537577.00000   537577.000000       537577.000000       370591.000000
# mean        8.08271        0.408797            5.295546            9.842144
# std         6.52412        0.491612            3.750701            5.087259
# min         0.00000        0.000000            1.000000            2.000000
# 25%         2.00000        0.000000            1.000000            5.000000
# 50%         7.00000        0.000000            5.000000            9.000000
# 75%        14.00000        1.000000            8.000000           15.000000
# max        20.00000        1.000000           18.000000           18.000000
#
#        Product_Category_3       Purchase
# count       164278.000000  537577.000000
# mean            12.669840    9333.859853
# std              4.124341    4981.022133
# min              3.000000     185.000000
# 25%              9.000000    5866.000000
# 50%             14.000000    8062.000000
# 75%             16.000000   12073.000000
# max             18.000000   23961.000000

# %% [markdown]
# # STEP-2 : Handling missing data

# %%
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            166986
# Product_Category_3            373299
# Purchase                           0
# dtype: int64

# %% [raw]
# filling the null values with 0.0 in Product_Category_2 and Product_Category_3 columns to get accurate results

# %%
df.fillna({'Product_Category_2':0.0,'Product_Category_3':0.0},inplace=True)

# %%
df.isnull().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Product_Category_2            0
# Product_Category_3            0
# Purchase                      0
# dtype: int64

# %% [markdown]
# # STEP-3 Analyzing Columns

# %%
col = []
for column in df.columns:
    lst = [column,df[column].nunique(),df[column].unique()]
    col.append(lst)
col_data = pd.DataFrame(col,columns=['Name','Number_of_Unique_values','Values'])

# %%
col_data
# Out:
#                           Name  Number_of_Unique_values  \
# 0                      User_ID                     5891
# 1                   Product_ID                     3623
# 2                       Gender                        2
# 3                          Age                        7
# 4                   Occupation                       21
# 5                City_Category                        3
# 6   Stay_In_Current_City_Years                        5
# 7               Marital_Status                        2
# 8           Product_Category_1                       18
# 9           Product_Category_2                       18
# 10          Product_Category_3                       16
# 11                    Purchase                    17959
#
#                                                Values
# 0   [1000001, 1000002, 1000003, 1000004, 1000005, ...
# 1   [P00069042, P00248942, P00087842, P00085442, P...
# 2                                              [F, M]
# 3      [0-17, 55+, 26-35, 46-50, 51-55, 36-45, 18-25]
# 4   [10, 16, 15, 7, 20, 9, 1, 12, 17, 0, 3, 4, 11,...
# 5                                           [A, C, B]
# 6                                    [2, 4+, 3, 1, 0]
# 7                                              [0, 1]
# 8   [3.0, 1.0, 12.0, 8.0, 5.0, 4.0, 2.0, 6.0, 14.0...
# 9   [0.0, 6.0, 14.0, 2.0, 8.0, 15.0, 16.0, 11.0, 5...
# 10  [0.0, 14.0, 17.0, 5.0, 4.0, 16.0, 15.0, 8.0, 9...
# 11  [8370, 15200, 1422, 1057, 7969, 15227, 19215, ...

# %%
df["Purchase"].sum()
# Out:
# 5017668378

# %%
df["Purchase"].sum()/len(df['Purchase'])
# Out:
# 9333.859852635065

# %% [markdown]
# ### 3.1 Analysing gender column

# %%
data = pd.DataFrame({'Ratio' : [len(df[df['Gender'] == 'M']),len(df[df['Gender'] == 'F'])]},
                    index = ['Male','Female'])
data
# Out:
#          Ratio
# Male    405380
# Female  132197

# %%
data.plot.pie(y = 'Ratio',figsize = (5,5),autopct = '%.1f')
# Out:
# <Axes: ylabel='Ratio'>

# %%
df.groupby('Gender').size().plot(kind = 'pie',autopct ='%.1f',
                                 title = 'Gender Ratio',figsize = (5,5))
# Out:
# <Axes: title={'center': 'Gender Ratio'}>

# %%
df.groupby('Gender').size().plot(kind = 'bar',figsize = (5,5))
# Out:
# <Axes: xlabel='Gender'>

# %% [raw]
# Here from the above 2 piecharts and 1 bargraph we can observe that the we have more male customers than female customers

# %%
df.groupby('Gender')['Purchase'].mean().plot(kind = 'pie',
                                             autopct = '%.1f',
                                             ylabel = '',legend=False)
# Out:
# <Axes: >

# %% [raw]
# The number of males who are purchasing the products are more than the number of females, but the spending amount of female is very nearer to the spending amount of the  male, that means females are purchasing the expensive products

# %% [markdown]
# ### 3.2 Analysing Age and Martial Status

# %%
df.groupby('Age').size().plot(kind='bar',figsize = (6,6),title='Purchase Distribution by Age')
# Out:
# <Axes: title={'center': 'Purchase Distribution by Age'}, xlabel='Age'>

# %% [raw]
# here we can observe that most of the customers are between the 26-35

# %%
lst = []
Age = []
for i in df['Age'].unique():
    lst = [i,df[df['Age'] == i]["Product_ID"].nunique()]
    Age.append(lst)
data = pd.DataFrame(Age,columns=["Age","No_of_unique_products"])
data
# Out:
#      Age  No_of_unique_products
# 0   0-17                   2300
# 1    55+                   2573
# 2  26-35                   3419
# 3  46-50                   3099
# 4  51-55                   2877
# 5  36-45                   3318
# 6  18-25                   3213

# %%
data.plot.bar(x = 'Age',y = 'No_of_unique_products',figsize=(8,6))
# Out:
# <Axes: xlabel='Age'>

# %%
lst = []
Age = []
for i in df['Age'].unique():
    lst = [i,df[df['Age'] == i]["Product_ID"].nunique(),
           df[df['Age'] == i]["Product_ID"].unique()]
    Age.append(lst)
Age_df = pd.DataFrame(Age,columns=["Age","No_of_unique_products","Unique_Product_ID"])
Age_df
# Out:
#      Age  No_of_unique_products  \
# 0   0-17                   2300
# 1    55+                   2573
# 2  26-35                   3419
# 3  46-50                   3099
# 4  51-55                   2877
# 5  36-45                   3318
# 6  18-25                   3213
#
#                                    Unique_Product_ID
# 0  [P00069042, P00248942, P00087842, P00085442, P...
# 1  [P00285442, P00117442, P00322042, P00216342, P...
# 2  [P00193542, P00274942, P00251242, P00014542, P...
# 3  [P00184942, P00346142, P0097242, P00129542, P0...
# 4  [P00231342, P00190242, P0096642, P00058442, P0...
# 5  [P00036842, P00085942, P00118742, P00297942, P...
# 6  [P00366542, P00190742, P00151842, P00112642, P...

# %% [raw]
# Customers who are between 26-35 and 36-45 age are purchasing more unique products than other customers

# %%
df.groupby('Age')['Purchase'].sum().plot(kind = 'bar',figsize=(8,6),title='Amount Spend by Age')
# Out:
# <Axes: title={'center': 'Amount Spend by Age'}, xlabel='Age'>

# %%
df.groupby('Age')['Purchase'].mean().plot(kind = 'bar',figsize=(8,6),title='Amount Spend by Age')
# Out:
# <Axes: title={'center': 'Amount Spend by Age'}, xlabel='Age'>

# %% [raw]
# From the above 2 graphs we can observe that, customers who are spending more amount are between the age 26-35 and the average amount spent
# by the customers in their respective Age categories are almost same

# %%
df.groupby('Marital_Status').size().plot(kind = 'pie',autopct = '%0.1f')
# Out:
# <Axes: >

# %%
df.groupby('Marital_Status')['Purchase'].sum().plot(kind = 'bar',figsize=(8,6),title='Amount Spend by Marital_Status')
# Out:
# <Axes: title={'center': 'Amount Spend by Age'}, xlabel='Marital_Status'>

# %% [raw]
# The amount spend by the unmarried customers are more than the amount spend by the married customers

# %% [markdown]
# ### 3.3 Combining the Gender and Marital_Status

# %%
l =[]
for i in range(len(df)):
    l.append(df['Gender'][i]+"_"+str(df["Marital_Status"][i]))
df["MaritalGender"] = l
# Out:
# 0         F_0
# 1         F_0
# 2         F_0
# 3         F_0
# 4         M_0
#          ...
# 537572    M_0
# 537573    M_0
# 537574    M_0
# 537575    M_0
# 537576    M_0
# Name: MaritalGender, Length: 537577, dtype: object

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                 3.0
# 1                          2               0                 1.0
# 2                          2               0                12.0
# 3                          2               0                12.0
# 4                         4+               0                 8.0
#
#    Product_Category_2  Product_Category_3  Purchase MaritalGender
# 0                 0.0                 0.0      8370           F_0
# 1                 6.0                14.0     15200           F_0
# 2                 0.0                 0.0      1422           F_0
# 3                14.0                 0.0      1057           F_0
# 4                 0.0                 0.0      7969           M_0

# %%
sns.countplot(x = df["MaritalGender"])
# Out:
# <Axes: xlabel='MaritalGender', ylabel='count'>

# %%
sns.countplot(x = df["Age"],hue= df["MaritalGender"])
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(x = df["Product_Category_1"],hue= df["MaritalGender"])
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='count'>

# %%
sns.countplot(x = df["Stay_In_Current_City_Years"],hue= df["MaritalGender"])
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x = df["City_Category"],hue= df["MaritalGender"])
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %% [raw]
# In the above graphs we can observe that the unmarried male customers are more than other category customers. We can sell more products to the male customers who are unmarried, so that we can increase our sales

# %% [markdown]
# ### 3.4 Creating a new column with Age Column

# %%
df["Age"].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
l = []
for i in df["Age"]:
    if i == '0-17':
        l.append('Youth')
    elif i == '26-35' or '18-25' or '36-45':
        l.append('Adult')
    else:
        l.append('Senior')
df["Age_Category"] = l

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                 3.0
# 1                          2               0                 1.0
# 2                          2               0                12.0
# 3                          2               0                12.0
# 4                         4+               0                 8.0
#
#    Product_Category_2  Product_Category_3  Purchase MaritalGender Age_Category
# 0                 0.0                 0.0      8370           F_0        Youth
# 1                 6.0                14.0     15200           F_0        Youth
# 2                 0.0                 0.0      1422           F_0        Youth
# 3                14.0                 0.0      1057           F_0        Youth
# 4                 0.0                 0.0      7969           M_0        Adult

# %%
sns.countplot(x = df["Product_Category_1"],hue= df["Age_Category"])
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='count'>

# %%
df.groupby('Age_Category')["Purchase"].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='Age_Category'>

# %% [raw]
# We can see that there is a large difference between number of customers who are adult and number of customers are youth,
# we can mainly concentrate on the adult customer products as they have more ratio

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                 3.0
# 1                          2               0                 1.0
# 2                          2               0                12.0
# 3                          2               0                12.0
# 4                         4+               0                 8.0
#
#    Product_Category_2  Product_Category_3  Purchase MaritalGender Age_Category
# 0                 0.0                 0.0      8370           F_0        Youth
# 1                 6.0                14.0     15200           F_0        Youth
# 2                 0.0                 0.0      1422           F_0        Youth
# 3                14.0                 0.0      1057           F_0        Youth
# 4                 0.0                 0.0      7969           M_0        Adult

# %%
df.groupby("City_Category")["Purchase"].sum().plot(kind = 'bar')
# Out:
# <Axes: xlabel='City_Category'>

# %% [raw]
# we are having more customers from the category B city

# %%
df.groupby("Occupation")["Purchase"].sum().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Occupation'>

# %% [markdown]
# ### 3.5 Multi Column Analysis

# %%
sns.set(rc = {"figure.figsize" : (12,6)})
sns.countplot(x = 'Age',hue = 'Gender',data=df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.set(rc = {"figure.figsize" : (12,6)})
sns.countplot(x = 'Gender',hue = 'Age',data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.set(rc = {"figure.figsize" : (12,6)})
sns.countplot(x = 'Gender',hue = 'Marital_Status',data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(x = 'City_Category',hue='Age',data=df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
sns.countplot(x = df["City_Category"])
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
df.groupby('City_Category').size().plot(kind = 'pie',autopct='%.1f')
# Out:
# <Axes: >

# %%
sns.countplot(x = 'City_Category', hue ='Gender',data=df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
df.groupby('City_Category')["Purchase"].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='City_Category'>

# %%
df.groupby('City_Category')["Purchase"].sum().plot(kind='pie',autopct = "%0.1f")
# Out:
# <Axes: ylabel='Purchase'>

# %%
df.groupby('City_Category')["Purchase"].mean().plot(kind='pie',autopct = "%0.1f")
# Out:
# <Axes: ylabel='Purchase'>

# %% [raw]
# we can observe that most of the orders are from the city B compared to other cities and also male customers are more than female customers
# but the average purchase amount is more for City C,that means the city C customers purchasing the expensive products

# %% [markdown]
# ### 3.6 Occupation and Products Analysis

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                 3.0
# 1                          2               0                 1.0
# 2                          2               0                12.0
# 3                          2               0                12.0
# 4                         4+               0                 8.0
#
#    Product_Category_2  Product_Category_3  Purchase MaritalGender Age_Category
# 0                 0.0                 0.0      8370           F_0        Youth
# 1                 6.0                14.0     15200           F_0        Youth
# 2                 0.0                 0.0      1422           F_0        Youth
# 3                14.0                 0.0      1057           F_0        Youth
# 4                 0.0                 0.0      7969           M_0        Adult

# %%
sns.countplot(x=df['Stay_In_Current_City_Years'])
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x='Stay_In_Current_City_Years',hue ='Gender',data=df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x='Stay_In_Current_City_Years',hue ='Marital_Status',data=df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x='Stay_In_Current_City_Years',hue ='City_Category',data=df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x='City_Category',data=df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
df.groupby("Stay_In_Current_City_Years")["Purchase"].sum().plot(kind = 'pie',autopct='%0.1f')
# Out:
# <Axes: ylabel='Purchase'>

# %%
df.groupby("Stay_In_Current_City_Years")["Purchase"].sum().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years'>

# %%
df.groupby("Stay_In_Current_City_Years")["Purchase"].mean().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years'>

# %%
sns.countplot(x = df['Occupation'])
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
df.groupby('Occupation').size().sort_values().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby('Occupation')["Purchase"].sum().sort_values().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby('Occupation')["Purchase"].mean().sort_values().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Occupation'>

# %%
sns.countplot(x = 'Occupation',hue = 'Marital_Status', data =df)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
sns.countplot(x = 'Occupation',hue = 'Gender', data =df)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
df.groupby('Occupation').nunique()["Product_ID"].plot(kind = 'bar')
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby('Occupation').nunique()["Product_ID"].sort_values().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby('Product_Category_1').size().sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
df.groupby('Product_Category_1')["Purchase"].sum().sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
df.groupby('Product_Category_1')["Purchase"].mean().sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
df.groupby('Product_ID')["Purchase"].sum().nlargest(10).sort_values().plot(kind='bar')
##Where they spend most money
# Out:
# <Axes: xlabel='Product_ID'>

# %%
df.groupby('Product_ID').size().nlargest(10).sort_values().plot(kind='bar')
## These are most selling products
# Out:
# <Axes: xlabel='Product_ID'>

# %%
df.groupby('Product_ID')["Purchase"].mean().nlargest(10).sort_values().plot(kind='bar')
##These are most expensive products
# Out:
# <Axes: xlabel='Product_ID'>
