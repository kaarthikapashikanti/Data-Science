# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("heart.csv")
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
df.isna().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Age, Sex, ChestPainType, RestingBP, Cholesterol, FastingBS, RestingECG, MaxHR, ExerciseAngina, Oldpeak, ST_Slope, HeartDisease]
# Index: []

# %% [markdown]
# ## 1) Dist Plot -Numerical columns

# %% [raw]
# It is used to visualise the distribution of the dataset. It shows the frequency and density
# of the data points within in a continous variable by displaying the probability density
# function (PDF) of the data. This type of plot helps you understand the shape of the data
# distribution—whether it's normal, skewed, or contains multiple modes.

# %%
sns.displot(df["Age"])

# %%
sns.distplot(df["Age"],kde = True,hist = True,rug = True)
# Out:
# C:\Users\pashi\AppData\Local\Temp\ipykernel_12100\3160477775.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Age"],kde = True,hist = True,rug = True)
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(df["RestingBP"],color='blue')
# Out:
# C:\Users\pashi\AppData\Local\Temp\ipykernel_12100\2945412985.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["RestingBP"],color='blue')
# <Axes: xlabel='RestingBP', ylabel='Density'>

# %%
sns.distplot(df["Cholesterol"],color='blue')
# Out:
# C:\Users\pashi\AppData\Local\Temp\ipykernel_12100\2288673608.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Cholesterol"],color='blue')
# <Axes: xlabel='Cholesterol', ylabel='Density'>

# %%
sns.distplot(df["FastingBS"],color='blue')
# Out:
# C:\Users\pashi\AppData\Local\Temp\ipykernel_12100\3197245445.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["FastingBS"],color='blue')
# <Axes: xlabel='FastingBS', ylabel='Density'>

# %%
sns.distplot(df["MaxHR"],color='blue')
# Out:
# C:\Users\pashi\AppData\Local\Temp\ipykernel_12100\3183233375.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["MaxHR"],color='blue')
# <Axes: xlabel='MaxHR', ylabel='Density'>

# %%
sns.distplot(df["Oldpeak"],color='blue')
# Out:
# C:\Users\pashi\AppData\Local\Temp\ipykernel_12100\1183887756.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Oldpeak"],color='blue')
# <Axes: xlabel='Oldpeak', ylabel='Density'>

# %% [raw]
# To know the distribution - displot or distplot
# to know the frequency - bargraph
# to know the frequency for categorical - pie chart --> if more catrgories

# %% [markdown]
# ## PieCharts - Categorical columns

# %%
df.groupby('Sex').size().plot(kind = 'pie',autopct = '%.1f')
# Out:
# <Axes: >

# %%
df.groupby('ChestPainType').size().plot(kind = 'pie',autopct = '%.1f')
# Out:
# <Axes: >

# %%
df.groupby('RestingECG').size().plot(kind = 'pie',autopct = '%.1f')
# Out:
# <Axes: >

# %%
df.groupby('ExerciseAngina').size().plot(kind = 'pie',autopct = '%.1f')
# Out:
# <Axes: >

# %%
df.groupby('ST_Slope').size().plot(kind = 'pie',autopct = '%.1f')
# Out:
# <Axes: >

# %%
df.groupby('HeartDisease').size().plot(kind = 'pie',autopct = '%.1f')
# Out:
# <Axes: >

# %% [markdown]
# # Violin Plot

# %% [raw]
# when you want to visualize the distribution of numeric data across different categories or groups

# %%
sns.violinplot(df["Age"])
# Out:
# <Axes: ylabel='Age'>

# %%
sns.violinplot(y = df["Sex"], x =df["HeartDisease"])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Sex'>

# %%
sns.violinplot(y = df["Age"], x =df["HeartDisease"])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Age'>

# %%
sns.violinplot(y = df["RestingBP"], x =df["HeartDisease"])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='RestingBP'>

# %%
sns.violinplot(y = df["Cholesterol"], x =df["HeartDisease"])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Cholesterol'>

# %% [markdown]
# # Heatmaps

# %% [raw]
# Heatmaps are used to show relationships between two variables, one plotted on each axis. By observing how cell colors change across each axis, you can observe if there are any patterns in value for one or both variables. The variables plotted on each axis can be of any type, whether they take on categorical labels or numeric values.

# %%
df.select_dtypes(include='number').corr()
# Out:
#                    Age  RestingBP  Cholesterol  FastingBS     MaxHR   Oldpeak  \
# Age           1.000000   0.254399    -0.095282   0.198039 -0.382045  0.258612
# RestingBP     0.254399   1.000000     0.100893   0.070193 -0.112135  0.164803
# Cholesterol  -0.095282   0.100893     1.000000  -0.260974  0.235792  0.050148
# FastingBS     0.198039   0.070193    -0.260974   1.000000 -0.131438  0.052698
# MaxHR        -0.382045  -0.112135     0.235792  -0.131438  1.000000 -0.160691
# Oldpeak       0.258612   0.164803     0.050148   0.052698 -0.160691  1.000000
# HeartDisease  0.282039   0.107589    -0.232741   0.267291 -0.400421  0.403951
#
#               HeartDisease
# Age               0.282039
# RestingBP         0.107589
# Cholesterol      -0.232741
# FastingBS         0.267291
# MaxHR            -0.400421
# Oldpeak           0.403951
# HeartDisease      1.000000

# %%
sns.heatmap(df.select_dtypes(include='number').corr())
# Out:
# <Axes: >

# %% [markdown]
# # Jointplot

# %% [raw]
# jointplot is another function from the seaborn library used for visualizing the relationship between two variables along with their individual distributions. It combines a scatter plot (or other bivariate plot) with marginal histograms (or KDE plots) on the axes.
# if correlation is actually there or not

# %%
sns.jointplot(x= 'Age',y = 'MaxHR',data=df)

# %%
sns.jointplot(x= 'Age',y = 'MaxHR',data=df,kind='reg')

# %%
sns.jointplot(x= 'Age',y = 'Age',data=df) #100% correlation

# %%
sns.jointplot(x= 'HeartDisease',y = 'Oldpeak',data=df) #100% correlation

# %%
sns.jointplot(x= 'Cholesterol',y = 'Oldpeak',data=df)

# %%
sns.jointplot(x = 'HeartDisease',y = 'MaxHR',data =df,kind = 'reg')

# %% [markdown]
# # PairPlot

# %% [raw]
# The pairplot function from the seaborn library is used to visualize relationships between pairs of variables in a dataset. It creates a matrix of scatter plots and histograms (or KDE plots) to show the pairwise relationships and distributions of numeric data.
# if there are many columns then it may take much time sometimes it may also out of memory

# %%
sns.pairplot(df)
